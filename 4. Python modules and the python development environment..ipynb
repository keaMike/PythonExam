# %% [markdown]
# # Python Modules & Development Environments

# %% [markdown]
# ### Modules

# %%
import mymodule

print(mymodule.string)
# Out:
# This is a message from a module

# %%
print(mymodule.module_list)
# Out:
# [1, 2, 4, 8, 16, 32, 64, 128]

# %%
mymodule.joke()
# Out:
# Why is lemons yellow?
# They do not know either...
# That is why they are bitter

# %%
from mymodule import string, module_list, joke # eller * for alle objekter

# %%
string
# Out:
# 'This is a message from a module'

# %%
module_list
# Out:
# [1, 2, 4, 8, 16, 32, 64, 128]

# %%
joke()
# Out:
# Why is lemons yellow?
# They do not know either...
# That is why they are bitter

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_11',
#  '_12',
#  '_13',
#  '_3',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'joke',
#  'module_list',
#  'mymodule',
#  'quit',
#  'string',
#  'sys']

# %%
dir(mymodule)
# Out:
# ['__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'joke',
#  'module_list',
#  'string']

# %% [markdown]
# ##### Request & beautifulsoup

# %%
import requests

page = requests.get('https://keamike.github.io/')

page.status_code
# Out:
# 200

# %%
from bs4 import BeautifulSoup

soup = BeautifulSoup(page.content, 'html.parser')

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Mike Eggertsen
#   </title>
#   <link href="/css/frontpage.css" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Poppins&amp;display=swap" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Nixie+One&amp;display=swap" rel="stylesheet"/>
#   <link href="https://fonts.googleapis.com/css?family=Raleway&amp;display=swap" rel="stylesheet"/>
#   <meta content="width=device-width, initial-scale=1, minimum-scale=1" name="viewport"/>
#   <script crossorigin="anonymous" src="https://kit.fontawesome.com/e0364b5885.js">
#   </script>
#   <script crossorigin="anonymous" integrity="sha256-BTlTdQO9/fascB1drekrDVkaKd9PkwBymMlHOiG+qLI=" src="https://code.jquery.com/jquery-3.4.1.slim.js">
#   </script>
#  </head>
#  <body>
#   <div class="frontpage section">
#    <nav class="navbar">
#     <div class="logo">
#      <h4 id="first">
#       Mike
# ...

# %%
dir(requests)
# Out:
# ['ConnectTimeout',
#  'ConnectionError',
#  'DependencyWarning',
#  'FileModeWarning',
#  'HTTPError',
#  'NullHandler',
#  'PreparedRequest',
#  'ReadTimeout',
#  'Request',
#  'RequestException',
#  'RequestsDependencyWarning',
#  'Response',
#  'Session',
#  'Timeout',
#  'TooManyRedirects',
#  'URLRequired',
#  '__author__',
#  '__author_email__',
#  '__build__',
#  '__builtins__',
#  '__cached__',
#  '__cake__',
#  '__copyright__',
#  '__description__',
#  '__doc__',
#  '__file__',
#  '__license__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__title__',
#  '__url__',
#  '__version__',
#  '_check_cryptography',
#  '_internal_utils',
#  'adapters',
#  'api',
#  'auth',
#  'certs',
#  'chardet',
#  'check_compatibility',
#  'codes',
#  'compat',
#  'cookies',
#  'delete',
#  'exceptions',
#  'get',
#  'head',
#  'hooks',
#  'logging',
#  'models',
#  'options',
#  'packages',
#  'patch',
#  'post',
#  'put',
#  'request',
#  'session',
# ...

# %% [markdown]
# ### Development Environments

# %% [markdown]
# #### REPL
# Read, Evaluate, Print, Loop
#
# ![REPL](images/REPL.jpg)
#
# #### Jupyter
# - REPL
# - IPython Kernel

# %%
a = 10

# %%
a
# Out:
# 10

# %% [markdown]
# #### Run Scripts Local

# %% [markdown]
# ![LocalScript](images/Script.jpg)

# %% [markdown]
# ![RunningScript](images/RunningScript.jpg)

# %% [markdown]
# ##### Docker
# docker run -it --rm -v ${PWD}:/script python bash

# %% [markdown]
# ![RunningScript](images/docker.jpg)
